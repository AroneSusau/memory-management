# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('ggplot')
pd.set_option('precision', 2)
sns.set_theme(color_codes=True)

# %%
data = pd.read_csv('./combined.csv')

# %%
list_type = (data["list"] == "FREE")

free = data[list_type]

sns.catplot(x="allocator", y="size", hue="allocator", kind="box", dodge=False, data=free)
plt.title("size usage by allocation strategy")
# Out:
# Text(0.5, 1.0, 'size usage by allocation strategy')

# %%
totals = pd.read_csv('./totals.csv')

sns.barplot(data=totals, y="allocator", x="memory_usage", hue="file")
plt.title("total memory usage by allocator")
# Out:
# Text(0.5, 1.0, 'total memory usage by allocator')

# %%
sns.histplot(x="size", hue="allocator", data=free, multiple="dodge", bins=20)
plt.title("size usage by allocation strategy")
# Out:
# Text(0.5, 1.0, 'size usage by allocation strategy')
